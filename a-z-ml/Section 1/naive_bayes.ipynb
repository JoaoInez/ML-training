# %%
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from visualize_classifier import visualize_classifier

# %%
data = np.loadtxt("../../input/data_multivar_nb.txt", delimiter=",")
data[:5]
# Out:
# array([[ 2.18,  0.57,  0.  ],
#        [ 4.13,  5.12,  1.  ],
#        [ 9.87,  1.95,  2.  ],
#        [ 4.02, -0.8 ,  3.  ],
#        [ 1.18,  1.03,  0.  ]])

# %%
X, y = data[:, :-1], data[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([3., 2., 1., 2., 1., 0., 1., 1., 2., 0., 1., 2., 3., 2., 2., 2., 3.,
#        0., 1., 3., 0., 3., 1., 0., 1., 3., 2., 2., 1., 3., 1., 1., 1., 1.,
#        0., 1., 3., 2., 1., 3., 2., 0., 2., 1., 0., 3., 3., 3., 0., 0., 1.,
#        2., 2., 1., 2., 3., 3., 0., 3., 3., 2., 2., 0., 0., 2., 1., 0., 3.,
#        1., 2., 2., 2., 0., 2., 3., 3., 1., 0., 0., 3., 0., 2., 2., 0., 3.,
#        0., 0., 3., 3., 1., 0., 3., 1., 1., 1., 0., 3., 1., 3., 2.])

# %%
visualize_classifier(model, X_test, y_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
precision_score(y_test, y_pred, average="weighted")
# Out:
# 1.0

# %%
recall_score(y_test, y_pred, average="weighted")
# Out:
# 1.0

# %%
f1_score(y_test, y_pred, average="weighted")
# Out:
# 1.0
