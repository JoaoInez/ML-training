# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import MeanShift, estimate_bandwidth
# %matplotlib inline

# %%
X = np.loadtxt("../input/data_clustering.txt", delimiter=",")
X[:5]
# Out:
# array([[2.08, 1.05],
#        [2.05, 7.7 ],
#        [4.53, 5.49],
#        [6.23, 1.02],
#        [5.35, 7.86]])

# %%
bandwidth = estimate_bandwidth(X, quantile=0.1, n_samples=len(X))

model = MeanShift(bandwidth=bandwidth, bin_seeding=True)
model.fit(X)
# Out:
# MeanShift(bandwidth=1.3044799765090382, bin_seeding=True)

# %%
print("Number of clusters: {}".format(len(np.unique(model.labels_))))
# Out:
# Number of clusters: 5

# %%
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=model.labels_, palette="deep")
sns.scatterplot(x=model.cluster_centers_[:, 0], y=model.cluster_centers_[:, 1], color="0", s=100, marker="s")
# Out:
# <AxesSubplot:>
